# %% [raw]
# # Maria owns a small coffee shop in the city.
# # Maria asks herself each morning: 'how much coffee should I prepare today?'
#
# - if she makes too much, it goes to waste
# - if she makes too little, customers leave disappointed
#
# Mon-Fri
# Temperature outside
# Cups Sold
#         Temperature(C) | Cups Sold
#
# Mon          15          120
# Tue          18          105
# Wed          10          145
# Thu          12          135
# Fri          20          95
#
# > If tommorow 8C, how many cups should Maria prepare?

# %% [raw]
# Linear regression draws the best possible straight line through your scattered data points.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
temperature = np.array([15, 18, 10, 12, 20, 8, 16, 14, 11, 19, 13, 17, 9, 22, 50]) # x axis
cups_sold = np.array([120, 105, 145, 135, 95, 155, 115, 125, 140, 100, 130, 110, 148, 88, 5]) # y axis

# %%
plt.scatter(temperature, cups_sold)
plt.xlabel('Temperature')
plt.ylabel('Cups Sold')
# Out:
# Text(0, 0.5, 'Cups Sold')

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(temperature, cups_sold) # linear regression (X, y)

line = slope * temperature + intercept

# %%
plt.scatter(temperature, cups_sold)
plt.plot(temperature, line, color='red') 
plt.grid()
plt.xlabel('Temperature')
plt.ylabel('Cups Sold')
# Out:
# Text(0, 0.5, 'Cups Sold')

# %%
slope
# SLOPE  tells us that for every 1C increase the temperature - Maria sells `-4.86` FEWER cups of coffee
# Out:
# np.float64(-3.5738416532981034)

# %%
intercept
# If it were 0C (freezing) - Maria would therotically sell 193 cups (This is the starting point of our line)
# Out:
# np.float64(174.91705199584788)

# %% [raw]
# y = mx + b # EVERY LINE has a simple equation
# x-input, temperature
# m-slope
# b-intercept

# %% [raw]
# Temperature matters, each degree change in temperature affects sales by ~4/5 cups.
# This gives Maria the power to predict and prepare accordingly.

# %%
def predict_cups(temperature: int | float):
    prediction = slope * temperature + intercept
    return prediction

# %%
tommorow_temperature = 48
predict_cups(tommorow_temperature)
# Out:
# np.float64(3.37265263753892)

# %%
# IMPORTANT LESSON: 
# Models work best within the range of data we trained them on.

# %%
std_err
# Out:
# np.float64(0.16351792249456953)
