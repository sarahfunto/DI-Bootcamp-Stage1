# %%
#exercise 1
#  What is data analysis?
#     Extraction of data to use it to answer a question or a hypothesis

# Why is data analysis important in modern contexts?
#     Data analysis is important because there is a large amount of data, and it allows us to process it quickly and provide evidence-based, data-driven arguments to answer questions efficiently.

# List and describe three areas where data analysis is applied today.
#     Genetics (gen, CMV)
#     Ecology and modeling the consequences of risky behaviors
#     Public health , exemple : disease prevention

# %%
#Exercise 2
import pandas as pd

# %%
pd.read_csv('genetic_data_test.csv')
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     2.517683  5.464283  9.067873 -4.965928 -0.741937  0.039785  0.573279
# 1     6.077012  1.032867 -5.795883 -3.490064 -0.600204 -0.120803  1.243767
# 2     1.016945 -2.913299  0.907702  1.233580 -1.983452  1.605964  2.674998
# 3   -10.860926  2.545077  0.023950 -1.474450  0.372286 -2.609954 -2.794092
# 4     4.790262  3.621650 -1.442221  5.459907 -0.864235 -2.591185 -0.062762
# ..         ...       ...       ...       ...       ...       ...       ...
# 106 -11.030349  1.712786 -1.392893 -0.163989  3.623641 -0.263645 -3.337796
# 107  -7.994173  0.045333 -0.738547  0.189793 -2.545140 -0.332066  0.026289
# 108  -8.874531  2.074620 -2.060999 -0.898143 -1.372896 -3.175091  2.325163
# 109  -7.017063 -0.199721 -1.469538 -1.997714  1.892038 -1.880466 -3.278863
# 110  -5.488129  0.406477 -0.852392  2.299789 -1.219706 -0.260295  0.204571
#
#           PC8       PC9      PC10         Ancestry
# ...

# %%
genetic_data_test = pd.read_csv("genetic_data_test.csv")

# %%
type(genetic_data_test)
# Out:
# pandas.core.frame.DataFrame

# %%
genetic_data_test.describe()
# Out:
#               PC1         PC2         PC3         PC4         PC5         PC6  \
# count  111.000000  111.000000  111.000000  111.000000  111.000000  111.000000
# mean    -2.428559    0.067684   -1.493551   -0.573465   -0.523544    0.063552
# std      5.711764    1.785841    1.737356    1.570952    1.684093    1.998561
# min    -12.099310   -3.626565   -5.796923   -4.965928   -4.193899   -5.595230
# 25%     -7.940556   -1.150346   -2.585205   -1.589435   -1.678536   -1.169095
# 50%      1.016945    0.085142   -1.392893   -0.659949   -0.639072   -0.084256
# 75%      2.881532    1.306610   -0.714361    0.291034    0.614935    1.178394
# max      6.077012    5.464283    9.067873    5.459907    3.830077    4.979169
#
#               PC7         PC8         PC9        PC10
# count  111.000000  111.000000  111.000000  111.000000
# mean     0.002549   -0.271733   -0.301580    0.086122
# std      1.961055    2.005613    1.571386    1.046801
# ...

# %%
genetic_data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   PC1       111 non-null    float64
#  1   PC2       111 non-null    float64
#  2   PC3       111 non-null    float64
#  3   PC4       111 non-null    float64
#  4   PC5       111 non-null    float64
#  5   PC6       111 non-null    float64
#  6   PC7       111 non-null    float64
#  7   PC8       111 non-null    float64
#  8   PC9       111 non-null    float64
#  9   PC10      111 non-null    float64
#  10  Ancestry  111 non-null    object
# dtypes: float64(10), object(1)
# memory usage: 9.7+ KB

# %%
genetic_data_test.shape
# Out:
# (111, 11)

# %%
type(genetic_data_test['PC3'])
# Out:
# pandas.core.series.Series

# %%
PC3 = genetic_data_test['PC3']
sum(PC3 < 1)
# Out:
# 108

# %%
sum(PC3 > 1)
# Out:
# 3

# %%
# #Exrercice 3
# The columns PC1 to PC10 are quantitative.Because they are numbers. 
# The column Ancestry is qualitative. Because it contains object. It does not contain numbers

# %%
#Exercise 4

# %%
import pandas as pd

# %%
df = pd.read_csv("iris.csv")

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.shape
# Out:
# (150, 6)

# %%
#exercicse 5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("iris.csv")

# %%
column = "SepalLengthCm"

# %%
mean_value = df[column].mean()
print(f"Mean of {column}: {mean_value}")
# Out:
# Mean of SepalLengthCm: 5.843333333333334

# %%
median_value = df[column].median()
print(f"Median of {column}: {median_value}")
# Out:
# Median of SepalLengthCm: 5.8

# %%
mode_value = df[column].mode()[0]
print(f"Mode of {column}: {mode_value}")
# Out:
# Mode of SepalLengthCm: 5.0

# %%
#exercice 6

# %%
import pandas as pd

# %%
pd.read_csv('Time Americans Spend Sleeping.csv')
# Out:
#      index  Year  Period  Avg hrs per day sleeping  Standard Error  \
# 0        0  2003  Annual                      8.57           0.018
# 1        1  2004  Annual                      8.55           0.026
# 2        2  2005  Annual                      8.62           0.023
# 3        3  2006  Annual                      8.63           0.024
# 4        4  2007  Annual                      8.57           0.024
# ..     ...   ...     ...                       ...             ...
# 940    940  2013  Annual                      8.83           0.085
# 941    941  2014  Annual                      8.98           0.086
# 942    942  2015  Annual                      8.83           0.074
# 943    943  2016  Annual                      8.92           0.071
# 944    944  2017  Annual                      8.81           0.091
#
#             Type of Days          Age Group  Activity    Sex
# 0               All days  15 years and over  Sleeping   Both
# ...

# %%
Time_Americans_Spend_Sleeping = pd.read_csv("Time Americans Spend Sleeping.csv")

# %%
Time_Americans_Spend_Sleeping.describe()
# Out:
#             index         Year  Avg hrs per day sleeping  Standard Error
# count  945.000000   945.000000                945.000000      945.000000
# mean   472.000000  2010.000000                  8.806868        0.086958
# std    272.942302     4.322782                  0.545001        0.034631
# min      0.000000  2003.000000                  7.720000        0.018000
# 25%    236.000000  2006.000000                  8.360000        0.063000
# 50%    472.000000  2010.000000                  8.810000        0.084000
# 75%    708.000000  2014.000000                  9.190000        0.106000
# max    944.000000  2017.000000                 10.650000        0.228000

# %%
import matplotlib.pyplot as plt
plt.plot(Time_Americans_Spend_Sleeping['Age Group'], Time_Americans_Spend_Sleeping['Sex'])
plt.show()
